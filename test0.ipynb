# %%
from Librarytest import hogehoge
x=1
hogehoge.hello(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from Librarytest import hogehoge
#       2 x=1
#       3 hogehoge.hello(x)
#
# ModuleNotFoundError: No module named 'Librarytest'

# %%
install Librarytest
# Out:
#   Cell In[11], line 1
#     install Librarytest
#             ^
# SyntaxError: invalid syntax

# %%
pip install pytest
# Out:
# ...
#    ---------------------------------------- 0.0/342.3 kB ? eta -:--:--
#    ---------------------- ----------------- 194.6/342.3 kB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 342.3/342.3 kB 5.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import Librarytest
x=1
Librarytest.hogehoge.hello(x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import Librarytest
#       2 x=1
#       3 Librarytest.hogehoge.hello(x)
#
# ModuleNotFoundError: No module named 'Librarytest'

# %%
from Librarytest import test2
x=1
test2.testtt(x,pix=10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from Librarytest import test2
#       2 x=1
#       3 test2.testtt(x,pix=10)
#
# ModuleNotFoundError: No module named 'Librarytest'

# %%
300**2
# Out:
# 90000

# %%
from Py2DFTIR import Read_tiffimage
import matplotlib.pyplot as plt
file = "C:/Users/daiki/N2O_data/1121/ref/"

x1,y1,z1 = Read_tiffimage.tiffr(file)
plt.contourf(x1,y1,z1[400,:,:])
plt.colorbar()
plt.show()
# Out:
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# ...

# %%
z1.shape[2]
# Out:
# 640

# %%
from Py2DFTIR import FFTVAv1
Zs_ref,Awav = FFTVAv1.FFTimage(z1)
plt.contourf(x1,y1,Zs_ref[300,:,:])
plt.colorbar()
plt.show()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 512/512 [03:32<00:00,  2.41it/s]

# %%
from Py2DFTIR import Read_tiffimage
import matplotlib.pyplot as plt
import numpy as np
path_ref = 'C:/Users/daiki/N2O_data/1121/ref/'
Zs_ref = 'np.zeros((len(yw),ny0,nx0))'
file = "C:/Users/daiki/N2O_data/1121/ref/"
x1,y1,z1 = Read_tiffimage.tiffr(file)
plt.contourf(x1,y1,z1[400,:,:])
plt.colorbar()
plt.show()
# Out:
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# TiffPage 0: TiffFileError: invalid tag value offset
# ...

# %%
from Py2DFTIR import FFTVAv1
#save directory
path_tg = 'C:/Users/daiki/N2O_data/1121/ref/'
Zs_tg,Awav = FFTVAv1.FFTimage(z1)
plt.contourf(x1,y1,Zs_tg[300,:,:])
plt.colorbar()
plt.show()
np.save(path_tg+'tg',Zs_tg)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 512/512 [02:50<00:00,  3.00it/s]

# %%
pip install Py2DFTIR
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement Py2DFTIR (from versions: none)
# ERROR: No matching distribution found for Py2DFTIR
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
sys.path.append('C:/Users/daiki/sokendai/N2O/experiment data/')

from Py2DFTIR import Read_tiffimage
import matplotlib.pyplot as plt
import numpy as np
import os

#path_sam = '20230721_143955_01tg/'
path_tg = 'C:/Users/daiki/sokendai/N2O/experiment data/UV/zipdata/1837/'
Zs_tg = 'np.zeros((len(yw),ny0,nx0))'
file ='C:/Users/daiki/sokendai/N2O/experiment data/UV/zipdata/1837/'



# ファイルの存在確認と読み込み
if os.path.exists(file):
    x1, y1, z1 = Read_tiffimage.tiffr(file) #read tiff image
    
    from Py2DFTIR import FFTVAv2
    #save directory
    path_tg = 'C:/Users/daiki/sokendai/N2O/experiment data/UV/zipdata/1837/'

    Zs_tg,Awav = FFTVAv2.FFTimage(z1)
    plt.contourf(x1,y1,Zs_tg[300,:,:])
    plt.colorbar()
    plt.show()
    np.save(path_tg+'tg',Zs_tg)
else:
    print(f"ファイルが見つかりません: {file}")
# Out:
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# <TiffTag.fromfile> raised TiffFileError('<tifffile.TiffTag 320 @154> invalid value offset 0')
# ...
